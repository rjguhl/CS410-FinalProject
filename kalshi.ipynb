# %%
import requests

# Get series information for KXHIGHNY
url = "https://api.elections.kalshi.com/trade-api/v2/series/KXHIGHNY"
response = requests.get(url)
series_data = response.json()

print(f"Series Title: {series_data['series']['title']}")
print(f"Frequency: {series_data['series']['frequency']}")
print(f"Category: {series_data['series']['category']}")
# Out:
# Series Title: Highest temperature in NYC
# Frequency: daily
# Category: Climate and Weather

# %%
import requests

# Get series information for KXHIGHNY
url = "https://api.elections.kalshi.com/trade-api/v2/search/tags_by_categories"
response = requests.get(url)
series_data = response.json()

print(series_data)
# Out:
# {'tags_by_categories': {'Climate and Weather': ['Daily temperature', 'Snow and rain', 'Climate change', 'Natural disasters', 'Hurricanes', 'Hourly temperature'], 'Commodities': ['Agriculture', 'Metals', 'Oil & Gas'], 'Companies': ['KPIs', 'IPOs', 'Product launches', 'Elon Musk', 'CEOs', 'Layoffs'], 'Crypto': ['BTC', '15 min', 'Hourly', 'ETH', 'SOL', 'DOGE', 'BNB', 'HYPE', 'XRP', 'Pre-Market'], 'Economics': ['Growth', 'Inflation', 'Jobs & Economy', 'Oil and energy', 'Fed', 'GDP', 'Global Central Banks', 'Housing', 'Econ Daily'], 'Elections': ['US Elections', 'Primaries', 'House', 'International elections', 'Senate', 'Governor', '2028', 'Brazil', 'Peru', 'Hungary'], 'Entertainment': ['Music', 'Awards', 'Television', 'People', 'Music charts', 'Anime Awards', 'Movies', 'Oscars', 'Emmys', 'ACMs', 'Video games', 'Live Music', 'Reality TV', 'Cannes', 'TV Charts', 'Grammys', 'Movie Charts', 'Eurovision', 'Music Streams', 'New Music', 'AMAs', 'Rotten Tomatoes', 'Vs'], 'Financials': ['S&P', 'Nasdaq', 'Daily', 'Treasuries', 'EUR/USD', 'USD/JPY'], 'Health': ['Diseases'], 'Mentions': ['Earnings', 'Politicians', 'Sports'], 'Politics': ['Trump', 'Congress', 'International', 'SCOTUS & courts', 'Recurring', 'Local', 'Iran'], 'Science and Technology': ['AI', 'Energy', 'Medicine', 'Space'], 'Social': None, 'Sports': ['Soccer', 'Baseball', 'Basketball', 'Football', 'Hockey', 'Golf', 'Motorsport', 'Tennis', 'MMA', 'Boxing', 'Esports', 'Cricket', 'Rugby', 'Chess', 'Lacrosse', 'Other', 'Aussie Rules', 'Darts']}}

# %%
import requests

# Example: Finding series related to the "Inflation" tag
tag_name = "Econ Daily"
url = f"https://api.elections.kalshi.com/trade-api/v2/series?tags={tag_name}"

response = requests.get(url)
series_data = response.json()

for series in series_data.get('series', []):
    print(f"Series Ticker: {series['ticker']} | Title: {series['title']}")
# Out:
# Series Ticker: KXTRUFPDEBT | Title: Total Public Debt
# Series Ticker: KXTRUFCPI | Title: Truflation US CPI Inflation Index
# Series Ticker: KXTRUFEGGS | Title: Truflation US CPI Eggs Index
# Series Ticker: KXTRUFDEAD | Title: Truflation Deadlift Index
# Series Ticker: KXTRUFAIDP | Title: Truflation AI & DePIN Index
# Series Ticker: KXAAAGASD | Title: US gas price up
# Series Ticker: KXTRUFBFST | Title: Truflation Breakfast Commodity Index
# Series Ticker: KXTRUFHOUCPI | Title: Truflation US CPI Housing Inflation Index
# Series Ticker: KXTRUFTSA | Title: Number of Airport Passenger Screened
# Series Ticker: KXTRUEV | Title: Truflation EV

# %%
series_ticker = "KXAAAGASD" 
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker={series_ticker}&status=open"

markets_response = requests.get(markets_url)
markets_json = markets_response.json()

for market in markets_json.get('markets', []):
    print(f"Market: {market['ticker']} | Yes Bid: ${market['yes_bid_dollars']}")
# Out:
# Market: KXAAAGASD-26APR27-4.145 | Yes Bid: $0.0000
# Market: KXAAAGASD-26APR27-4.140 | Yes Bid: $0.0000
# Market: KXAAAGASD-26APR27-4.135 | Yes Bid: $0.0000
# Market: KXAAAGASD-26APR27-4.130 | Yes Bid: $0.0100
# Market: KXAAAGASD-26APR27-4.125 | Yes Bid: $0.0100
# Market: KXAAAGASD-26APR27-4.120 | Yes Bid: $0.0200
# Market: KXAAAGASD-26APR27-4.115 | Yes Bid: $0.1100
# Market: KXAAAGASD-26APR27-4.110 | Yes Bid: $0.2100
# Market: KXAAAGASD-26APR27-4.105 | Yes Bid: $0.9000
# Market: KXAAAGASD-26APR27-4.100 | Yes Bid: $0.9100
# Market: KXAAAGASD-26APR27-4.095 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.090 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.085 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.080 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.075 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.070 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.065 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.060 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.055 | Yes Bid: $0.9900
# Market: KXAAAGASD-26APR27-4.050 | Yes Bid: $0.9900

# %%
# Get all open markets for the KXHIGHNY series
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker={series_ticker}&status=open"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

print(f"\nActive markets in {series_ticker} series:")
for market in markets_data['markets']:
    print(f"- {market['ticker']}: {market['title']}")
    print(f"  Event: {market['event_ticker']}")
    print(f"  Yes Price: ${market['yes_bid_dollars']} | Volume: {market['volume_fp']}")
    print()

# Get details for a specific event if you have its ticker
if markets_data['markets']:
    # Let's get details for the first market's event
    event_ticker = markets_data['markets'][0]['event_ticker']
    event_url = f"https://api.elections.kalshi.com/trade-api/v2/events/{event_ticker}"
    event_response = requests.get(event_url)
    event_data = event_response.json()

    print(f"Event Details:")
    print(f"Title: {event_data['event']['title']}")
    print(f"Category: {event_data['event']['category']}")
# Out:
# Active markets in KXAAAGASD series:
# - KXAAAGASD-26APR27-4.145: Will average **gas prices** be above $4.145?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.0000 | Volume: 1052.59
#
# - KXAAAGASD-26APR27-4.140: Will average **gas prices** be above $4.140?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.0000 | Volume: 592.80
#
# - KXAAAGASD-26APR27-4.135: Will average **gas prices** be above $4.135?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.0000 | Volume: 585.00
#
# - KXAAAGASD-26APR27-4.130: Will average **gas prices** be above $4.130?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.0100 | Volume: 828.32
#
# - KXAAAGASD-26APR27-4.125: Will average **gas prices** be above $4.125?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.0100 | Volume: 10.05
#
# - KXAAAGASD-26APR27-4.120: Will average **gas prices** be above $4.120?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.0200 | Volume: 132.67
#
# - KXAAAGASD-26APR27-4.115: Will average **gas prices** be above $4.115?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.1100 | Volume: 80.63
#
# - KXAAAGASD-26APR27-4.110: Will average **gas prices** be above $4.110?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.2100 | Volume: 387.67
#
# - KXAAAGASD-26APR27-4.105: Will average **gas prices** be above $4.105?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9000 | Volume: 386.37
#
# - KXAAAGASD-26APR27-4.100: Will average **gas prices** be above $4.100?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9100 | Volume: 0.00
#
# - KXAAAGASD-26APR27-4.095: Will average **gas prices** be above $4.095?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 985.81
#
# - KXAAAGASD-26APR27-4.090: Will average **gas prices** be above $4.090?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 773.02
#
# - KXAAAGASD-26APR27-4.085: Will average **gas prices** be above $4.085?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 586.00
#
# - KXAAAGASD-26APR27-4.080: Will average **gas prices** be above $4.080?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 586.00
#
# - KXAAAGASD-26APR27-4.075: Will average **gas prices** be above $4.075?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 586.00
#
# - KXAAAGASD-26APR27-4.070: Will average **gas prices** be above $4.070?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 586.00
#
# - KXAAAGASD-26APR27-4.065: Will average **gas prices** be above $4.065?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 586.00
#
# - KXAAAGASD-26APR27-4.060: Will average **gas prices** be above $4.060?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 586.00
#
# - KXAAAGASD-26APR27-4.055: Will average **gas prices** be above $4.055?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 586.00
#
# - KXAAAGASD-26APR27-4.050: Will average **gas prices** be above $4.050?
#   Event: KXAAAGASD-26APR27
#   Yes Price: $0.9900 | Volume: 594.06
#
# Event Details:
# Title: US gas prices on Apr 27, 2026
# Category: Economics

# %%
# Get orderbook for a specific market
# Replace with an actual market ticker from the markets list
if not markets_data['markets']:
    raise ValueError("No open markets found. Try removing status=open or choose another series.")

market_ticker = markets_data['markets'][0]['ticker']
orderbook_url = f"https://api.elections.kalshi.com/trade-api/v2/markets/{market_ticker}/orderbook"

orderbook_response = requests.get(orderbook_url)
orderbook_data = orderbook_response.json()

print(f"\nOrderbook for {market_ticker}:")
print("YES BIDS:")
for price_dollars, count_fp in orderbook_data['orderbook_fp']['yes_dollars'][:5]:  # Show top 5
    print(f"  Price: ${price_dollars}, Quantity: {count_fp}")

print("\nNO BIDS:")
for price_dollars, count_fp in orderbook_data['orderbook_fp']['no_dollars'][:5]:  # Show top 5
    print(f"  Price: ${price_dollars}, Quantity: {count_fp}")
# Out:
# Orderbook for KXHIGHNY-26MAR30-T69:
# YES BIDS:
#   Price: $0.0100, Quantity: 705.00
#   Price: $0.0200, Quantity: 329.00
#   Price: $0.0300, Quantity: 640.00
#   Price: $0.0400, Quantity: 115.00
#   Price: $0.0500, Quantity: 295.00
#
# NO BIDS:
#   Price: $0.0100, Quantity: 1105.00
#   Price: $0.0300, Quantity: 172.00
#   Price: $0.0400, Quantity: 86.00
#   Price: $0.0500, Quantity: 40.00
#   Price: $0.0600, Quantity: 100.00
