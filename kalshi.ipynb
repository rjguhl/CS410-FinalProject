# %%
import requests

# Get series information for KXHIGHNY
url = "https://api.elections.kalshi.com/trade-api/v2/series/KXHIGHNY"
response = requests.get(url)
series_data = response.json()

print(f"Series Title: {series_data['series']['title']}")
print(f"Frequency: {series_data['series']['frequency']}")
print(f"Category: {series_data['series']['category']}")
# Out:
# Series Title: Highest temperature in NYC
# Frequency: daily
# Category: Climate and Weather

# %%
import requests

# Get series information for KXHIGHNY
url = "https://api.elections.kalshi.com/trade-api/v2/search/tags_by_categories"
response = requests.get(url)
series_data = response.json()

print(series_data)
# Out:
# {'tags_by_categories': {'Climate and Weather': ['Daily temperature', 'Snow and rain', 'Climate change', 'Natural disasters', 'Hurricanes', 'Hourly temperature'], 'Companies': ['Product launches', 'IPOs', 'Elon Musk', 'KPIs', 'CEOs', 'Layoffs'], 'Crypto': ['BTC', '15 min', 'Hourly', 'ETH', 'SOL', 'DOGE', 'Pre-Market', 'XRP', 'BNB', 'HYPE'], 'Economics': ['Growth', 'Inflation', 'Oil and energy', 'Jobs & Economy', 'Fed', 'Global Central Banks', 'Housing', 'GDP'], 'Elections': ['Primaries', 'International elections', 'US Elections'], 'Entertainment': ['Music', 'Movies', 'Television', 'Music charts', 'Awards', 'Video games', 'Oscars', 'Rotten Tomatoes'], 'Financials': ['S&P', 'Metals', 'Nasdaq', 'Oil & Gas', 'Daily', 'Treasuries', 'EUR/USD', 'USD/JPY'], 'Health': ['Diseases'], 'Mentions': ['Politicians', 'Earnings', 'Sports'], 'Politics': ['Trump', 'Congress', 'International', 'SCOTUS & courts', 'Local', 'Recurring', 'Iran'], 'Science and Technology': ['AI', 'Energy', 'Medicine', 'Space'], 'Social': None, 'Sports': ['Soccer', 'Basketball', 'Baseball', 'Football', 'Hockey', 'Golf', 'Motorsport', 'Tennis', 'Esports', 'Boxing', 'MMA', 'Rugby', 'Chess', 'Lacrosse', 'Cricket', 'Aussie Rules', 'Darts'], 'World': None}}

# %%
import requests

# Example: Finding series related to the "Inflation" tag
tag_name = "Nasdaq"
url = f"https://api.elections.kalshi.com/trade-api/v2/series?tags={tag_name}"

response = requests.get(url)
series_data = response.json()

for series in series_data.get('series', []):
    print(f"Series Ticker: {series['ticker']} | Title: {series['title']}")
# Out:
# Series Ticker: KXNASDAQ100MAXY | Title: Nasdaq max yearly
# Series Ticker: KXNASDAQ100U | Title: Nasdaq above/below
# Series Ticker: KXNASDAQ100Y | Title: Nasdaq yearly range
# Series Ticker: KXNASDAQ100M | Title: Nasdaq range
# Series Ticker: KXNASDAQ100MINY | Title: NASDAQ100 Min
# Series Ticker: NASDAQ100U | Title: Nasdaq above/below
# Series Ticker: NASDAQ100M | Title: Nasdaq range
# Series Ticker: NASDAQ100W | Title: Nasdaq range
# Series Ticker: KXNASDAQ100EU | Title: Nasdaq-100 DAY AFTER ELECTION
# Series Ticker: KXNASDAQ100E | Title: Nasdaq-100 election day
# Series Ticker: NASDAQ100Y | Title: Nasdaq yearly range
# Series Ticker: KXNASDAQ100Z | Title: Nasdaq up
# Series Ticker: KXNASDAQ100POS | Title: NASDAQ100 Positive
# Series Ticker: KXNASDAQ100W | Title: Nasdaq range
# Series Ticker: NASDAQ100 | Title: Nasdaq range
# Series Ticker: KXNASDAQ100 | Title: Nasdaq range
# Series Ticker: NASDAQ100Z | Title: Nasdaq up
# Series Ticker: NASDAQ100I | Title: Nasdaq-100 hourly

# %%
series_ticker = "KXNASDAQ100MAXY" 
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker={series_ticker}&status=open"

markets_response = requests.get(markets_url)
markets_json = markets_response.json()

for market in markets_json.get('markets', []):
    print(f"Market: {market['ticker']} | Yes Bid: ${market['yes_bid_dollars']}")
# Out:
# Market: KXNASDAQ100MAXY-26DEC31H1600-T29999.99 | Yes Bid: $0.1000
# Market: KXNASDAQ100MAXY-26DEC31H1600-T29499.99 | Yes Bid: $0.1220
# Market: KXNASDAQ100MAXY-26DEC31H1600-T28999.99 | Yes Bid: $0.1400
# Market: KXNASDAQ100MAXY-26DEC31H1600-T28799.99 | Yes Bid: $0.1600
# Market: KXNASDAQ100MAXY-26DEC31H1600-T28599.99 | Yes Bid: $0.1800
# Market: KXNASDAQ100MAXY-26DEC31H1600-T28399.99 | Yes Bid: $0.2000
# Market: KXNASDAQ100MAXY-26DEC31H1600-T28199.99 | Yes Bid: $0.2200
# Market: KXNASDAQ100MAXY-26DEC31H1600-T27999.99 | Yes Bid: $0.2600
# Market: KXNASDAQ100MAXY-26DEC31H1600-T27799.99 | Yes Bid: $0.2800
# Market: KXNASDAQ100MAXY-26DEC31H1600-T27599.99 | Yes Bid: $0.3100
# Market: KXNASDAQ100MAXY-26DEC31H1600-T27399.99 | Yes Bid: $0.3300
# Market: KXNASDAQ100MAXY-26DEC31H1600-T27199.99 | Yes Bid: $0.3600
# Market: KXNASDAQ100MAXY-26DEC31H1600-T26999.99 | Yes Bid: $0.3900
# Market: KXNASDAQ100MAXY-26DEC31H1600-T26799.99 | Yes Bid: $0.4100
# Market: KXNASDAQ100MAXY-26DEC31H1600-T26599.99 | Yes Bid: $0.4400
# Market: KXNASDAQ100MAXY-26DEC31H1600-T26399.99 | Yes Bid: $0.4800
# Market: KXNASDAQ100MAXY-26DEC31H1600-T26199.99 | Yes Bid: $0.5100
# Market: KXNASDAQ100MAXY-26DEC31H1600-T25999.99 | Yes Bid: $0.5300
# Market: KXNASDAQ100MAXY-26DEC31H1600-T25799.99 | Yes Bid: $0.5800
# Market: KXNASDAQ100MAXY-26DEC31H1600-T25599.99 | Yes Bid: $0.6300

# %%
# Get all open markets for the KXHIGHNY series
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker={series_ticker}&status=open"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

print(f"\nActive markets in {series_ticker} series:")
for market in markets_data['markets']:
    print(f"- {market['ticker']}: {market['title']}")
    print(f"  Event: {market['event_ticker']}")
    print(f"  Yes Price: ${market['yes_bid_dollars']} | Volume: {market['volume_fp']}")
    print()

# Get details for a specific event if you have its ticker
if markets_data['markets']:
    # Let's get details for the first market's event
    event_ticker = markets_data['markets'][0]['event_ticker']
    event_url = f"https://api.elections.kalshi.com/trade-api/v2/events/{event_ticker}"
    event_response = requests.get(event_url)
    event_data = event_response.json()

    print(f"Event Details:")
    print(f"Title: {event_data['event']['title']}")
    print(f"Category: {event_data['event']['category']}")
# Out:
# Active markets in KXNASDAQ100MAXY series:
# - KXNASDAQ100MAXY-26DEC31H1600-T29999.99: Will the Nasdaq-100 be above 29999.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.1000 | Volume: 2336.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T29499.99: Will the Nasdaq-100 be above 29499.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.1220 | Volume: 5225.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T28999.99: Will the Nasdaq-100 be above 28999.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.1400 | Volume: 1582.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T28799.99: Will the Nasdaq-100 be above 28799.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.1600 | Volume: 64.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T28599.99: Will the Nasdaq-100 be above 28599.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.1800 | Volume: 390.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T28399.99: Will the Nasdaq-100 be above 28399.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.2000 | Volume: 116.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T28199.99: Will the Nasdaq-100 be above 28199.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.2200 | Volume: 350.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T27999.99: Will the Nasdaq-100 be above 27999.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.2600 | Volume: 555.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T27799.99: Will the Nasdaq-100 be above 27799.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.2800 | Volume: 379.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T27599.99: Will the Nasdaq-100 be above 27599.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.3100 | Volume: 68.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T27399.99: Will the Nasdaq-100 be above 27399.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.3300 | Volume: 189.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T27199.99: Will the Nasdaq-100 be above 27199.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.3600 | Volume: 297.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T26999.99: Will the Nasdaq-100 be above 26999.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.3900 | Volume: 197.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T26799.99: Will the Nasdaq-100 be above 26799.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.4100 | Volume: 271.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T26599.99: Will the Nasdaq-100 be above 26599.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.4400 | Volume: 4416.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T26399.99: Will the Nasdaq-100 be above 26399.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.4800 | Volume: 256.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T26199.99: Will the Nasdaq-100 be above 26199.99  after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.5100 | Volume: 1331.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T25999.99: Will the Nasdaq-100 be above 25999.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.5300 | Volume: 8413.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T25799.99: Will the Nasdaq-100 be above 25799.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.5800 | Volume: 11061.00
#
# - KXNASDAQ100MAXY-26DEC31H1600-T25599.99: Will the Nasdaq-100 be above 25599.99 after issuance and before Dec 31, 2026 at 4pm EST?
#   Event: KXNASDAQ100MAXY-26DEC31H1600
#   Yes Price: $0.6300 | Volume: 30592.00
#
# Event Details:
# Title: How high will the Nasdaq-100 price get in 2026?
# Category: Financials

# %%
# Get orderbook for a specific market
# Replace with an actual market ticker from the markets list
if not markets_data['markets']:
    raise ValueError("No open markets found. Try removing status=open or choose another series.")

market_ticker = markets_data['markets'][0]['ticker']
orderbook_url = f"https://api.elections.kalshi.com/trade-api/v2/markets/{market_ticker}/orderbook"

orderbook_response = requests.get(orderbook_url)
orderbook_data = orderbook_response.json()

print(f"\nOrderbook for {market_ticker}:")
print("YES BIDS:")
for price_dollars, count_fp in orderbook_data['orderbook_fp']['yes_dollars'][:5]:  # Show top 5
    print(f"  Price: ${price_dollars}, Quantity: {count_fp}")

print("\nNO BIDS:")
for price_dollars, count_fp in orderbook_data['orderbook_fp']['no_dollars'][:5]:  # Show top 5
    print(f"  Price: ${price_dollars}, Quantity: {count_fp}")
# Out:
# Orderbook for KXHIGHNY-26MAR30-T69:
# YES BIDS:
#   Price: $0.0100, Quantity: 705.00
#   Price: $0.0200, Quantity: 329.00
#   Price: $0.0300, Quantity: 640.00
#   Price: $0.0400, Quantity: 115.00
#   Price: $0.0500, Quantity: 295.00
#
# NO BIDS:
#   Price: $0.0100, Quantity: 1105.00
#   Price: $0.0300, Quantity: 172.00
#   Price: $0.0400, Quantity: 86.00
#   Price: $0.0500, Quantity: 40.00
#   Price: $0.0600, Quantity: 100.00
